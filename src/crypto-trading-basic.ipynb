# %% [markdown]
# # Alpaca-py crypto trading basic

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alpacahq/alpaca-py/blob/master/examples/crypto-trading-basic.ipynb)

# %% [markdown]
# - This notebook shows how to use alpaca-py with crypto trading API endpoints
# - Please use ``paper account``. Please ``DO NOT`` use this notebook with live account. In this notebook, we place orders for crypto as an example.

# %%
# Please change the following to your own PAPER api key and secret
# or set them as environment variables (ALPACA_API_KEY, ALPACA_SECRET_KEY).
# You can get them from https://alpaca.markets/
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
api_key = None
secret_key = None
TRADE_API_KEY=api_key
TRADE_API_SECRET=secret_key

#### We use paper environment for this example ####
paper = True # Please do not modify this. This example is for paper trading only.
####

# Below are the variables for development this documents
# Please do not change these variables
trade_api_url = None
trade_api_wss = None
data_api_url = None
stream_data_wss = None

# %%
import os

if api_key is None:
    api_key = os.environ.get('ALPACA_API_KEY')

if secret_key is None:
    secret_key = os.environ.get('ALPACA_SECRET_KEY')

# %%
# install alpaca-py if it is not available
try:
    import alpaca
except ImportError:
    # !python3 -m pip install alpaca-py
    import alpaca

# %%
import json
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

from alpaca.trading.client import TradingClient
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
from alpaca.data.historical.crypto import CryptoHistoricalDataClient
from alpaca.trading.stream import TradingStream
from alpaca.data.live.crypto import CryptoDataStream

from alpaca.data.requests import (
    CryptoBarsRequest,
    CryptoQuoteRequest,
    CryptoTradesRequest,
    CryptoLatestQuoteRequest
    )
from alpaca.trading.requests import (
    GetAssetsRequest,
    MarketOrderRequest,
    LimitOrderRequest,
    StopLimitOrderRequest,
    GetOrdersRequest,
    ClosePositionRequest
)
from alpaca.trading.enums import (
    AssetClass,
    AssetStatus,
    OrderSide,
    OrderType,
    TimeInForce,
    QueryOrderStatus
)
from alpaca.common.exceptions import APIError

# %%
# to run async code in jupyter notebook
import nest_asyncio
nest_asyncio.apply()

# %%
# check version of alpaca-py
alpaca.__version__

# %% [markdown]
# # Trading Client

# %%
# setup clients
trade_client = TradingClient(api_key=api_key, secret_key=secret_key, paper=paper, url_override=trade_api_url)

# %%
# check trading account
# You can check definition of each field in the following documents
# ref. https://docs.alpaca.markets/docs/account-plans
# ref. https://docs.alpaca.markets/reference/getaccount-1
acct = trade_client.get_account()
acct

# %%
# check account configuration
# ref. https://docs.alpaca.markets/reference/getaccountconfig-1
acct_config = trade_client.get_account_configurations()
acct_config

# %%
# get list of crypto pairs
# ref. https://docs.alpaca.markets/reference/get-v2-assets-1
req = GetAssetsRequest(
  asset_class=AssetClass.CRYPTO,
  status=AssetStatus.ACTIVE
)
assets = trade_client.get_all_assets(req)
assets[:2]

# %% [markdown]
# ### Orders

# %%
# we will place orders which Alapca trading platform supports
# - order types for crypto: market, limit, stop_limit
# - time_in_force for crypto: gtc, ioc.
# please refer to the following documents for more details
# ref. https://docs.alpaca.markets/docs/orders-at-alpaca
# ref. https://docs.alpaca.markets/reference/postorder


# we will place orders for symbol: BTC/USD in this example
symbol = "BTC/USD"

# %%
# simple, market order
# you can specify:
# or notional value (e.g. 100 USD) (which is in the next example)
req = MarketOrderRequest(
    symbol = symbol,
    qty = 0.01,
    side = OrderSide.BUY,
    type = OrderType.MARKET,
    time_in_force = TimeInForce.GTC,
)
res = trade_client.submit_order(req)
res

# %%
# simple, market order, notional

req = MarketOrderRequest(
    symbol = symbol,
    notional = 11.1,  # notional is specified in USD, here we specify $1.11
    side = OrderSide.BUY,
    type = OrderType.MARKET,
    time_in_force = TimeInForce.GTC,
)
res = trade_client.submit_order(req)
res

# %%
# simple, limit order
req = LimitOrderRequest(
    symbol = symbol,
    qty = 0.01,
    limit_price = 60000,
    side = OrderSide.BUY,
    type = OrderType.LIMIT,
    time_in_force = TimeInForce.GTC,
)
res = trade_client.submit_order(req)
res

# %%
# stop limit order
req = StopLimitOrderRequest(
                    symbol = symbol,
                    qty = 0.01,
                    side = OrderSide.BUY,
                    time_in_force = TimeInForce.GTC,
                    limit_price = 55000,
                    stop_price = 60000
                    )

res = trade_client.submit_order(req)
res

# %%
# get a list of orders including closed (e.g. filled) orders by specifying symbol
req = GetOrdersRequest(
    status = QueryOrderStatus.ALL,
    symbols = [symbol]
)
orders = trade_client.get_orders(req)
orders

# %%
# see all open orders
req = GetOrdersRequest(
    status = QueryOrderStatus.OPEN,
    symbols = [symbol]
)
open_orders = trade_client.get_orders(req)
open_orders

# %%
# cancel all open orders
trade_client.cancel_orders()

# %% [markdown]
# ### Positions

# %%
# '/' not being supported for position calls
symbol="BTCUSD"

# %%
# get all open positions
# ref. https://docs.alpaca.markets/reference/getallopenpositions-1
positions = trade_client.get_all_positions()
positions

# %%
# get positions by symbol
# ref. https://docs.alpaca.markets/reference/getopenposition-1
position = trade_client.get_open_position(symbol_or_asset_id=symbol)
position

# %%
# get positions by asset_id
trade_client.get_open_position(symbol_or_asset_id=position.asset_id)

# %%
# close the position with specifying qty
# ref. https://docs.alpaca.markets/reference/deleteopenposition-1
trade_client.close_position(
    symbol_or_asset_id = symbol,
    close_options = ClosePositionRequest(
        qty = "0.01",
    )
)

# %% [markdown]
# # Trade Update (Stream)

# %% [markdown]
# With TradingStream client, you can get updates about trades
#
# You can open this notebook in another window and run below cell to check trade updates.

# %%
# subscribe trade updates
trade_stream_client = TradingStream(api_key, secret_key, paper=paper, url_override = trade_api_wss)

async def trade_updates_handler(data):
    print(data)

trade_stream_client.subscribe_trade_updates(trade_updates_handler)
trade_stream_client.run()
# Out:
# event='pending_new' execution_id=None order={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': None,
#     'client_order_id': '96195073-ab3e-47fa-bfa4-fd01e2802325',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 428104, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('95d573c6-03cc-4d42-9547-05c15a793e9e'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 428104, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 429327, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 46, 17, 430570, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None
# event='new' execution_id=UUID('5ed6f3ab-5ca4-4f86-a318-7c7ba0349b30') order={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': None,
#     'client_order_id': '96195073-ab3e-47fa-bfa4-fd01e2802325',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 428104, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('95d573c6-03cc-4d42-9547-05c15a793e9e'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.NEW: 'new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 433044, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 46, 17, 434249, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 46, 17, 433044, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None
# event='pending_new' execution_id=None order={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': None,
#     'client_order_id': '7f5675ff-628d-4a9a-8ffe-faa5cef31a3a',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 47, 11, 995095, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('af21b2d6-cc27-4256-8d7b-2910abdb5f43'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 47, 11, 995095, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 47, 11, 996293, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 47, 11, 998015, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None
# event='new' execution_id=UUID
={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': None,
#     'client_order_id': '7c57fb63-ece8-4cd8-a37b-5ded1006719d',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 895469, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('2db40610-914e-487b-aa7f-d6657c8f54a2'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.PENDING_NEW: 'pending_new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 895469, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 904223, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 58, 24, 905761, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None
# event='new' execution_id=UUID('ca8ed026-8232-4f7c-bc9b-cf0420d6c2a4') order={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': None,
#     'client_order_id': '7c57fb63-ece8-4cd8-a37b-5ded1006719d',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 895469, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('2db40610-914e-487b-aa7f-d6657c8f54a2'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.NEW: 'new'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 909334, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 910310, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 58, 24, 909333, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None
# event='canceled' execution_id=UUID('ba1269df-a093-46c6-9948-ac078e5574e5') order={   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#     'asset_id': UUID('4ce9353c-66d1-46c2-898f-fce867ab0247'),
#     'canceled_at': datetime.datetime(2025, 2, 4, 9, 58, 41, 224551, tzinfo=TzInfo(UTC)),
#     'client_order_id': '7c57fb63-ece8-4cd8-a37b-5ded1006719d',
#     'created_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 895469, tzinfo=TzInfo(UTC)),
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': UUID('2db40610-914e-487b-aa7f-d6657c8f54a2'),
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': <OrderClass.SIMPLE: 'simple'>,
#     'order_type': <OrderType.MARKET: 'market'>,
#     'position_intent': <PositionIntent.SELL_TO_OPEN: 'sell_to_open'>,
#     'qty': '142',
#     'ratio_qty': None,
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': <OrderSide.SELL: 'sell'>,
#     'status': <OrderStatus.CANCELED: 'canceled'>,
#     'stop_price': None,
#     'submitted_at': datetime.datetime(2025, 2, 4, 9, 58, 24, 909334, tzinfo=TzInfo(UTC)),
#     'symbol': 'NVDA',
#     'time_in_force': <TimeInForce.DAY: 'day'>,
#     'trail_percent': None,
#     'trail_price': None,
#     'type': <OrderType.MARKET: 'market'>,
#     'updated_at': datetime.datetime(2025, 2, 4, 9, 58, 41, 226409, tzinfo=TzInfo(UTC))} timestamp=datetime.datetime(2025, 2, 4, 9, 58, 41, 224551, tzinfo=TzInfo(UTC)) position_qty=None price=None qty=None

# %% [markdown]
# # Market Data (Historical)

# %%
# setup crypto historical data client
crypto_historical_data_client = CryptoHistoricalDataClient()

symbol="BTC/USD"

# %%
# get historical bars by symbol
# ref. https://docs.alpaca.markets/reference/cryptobars-1
now = datetime.now(ZoneInfo("America/New_York"))
req = CryptoBarsRequest(
    symbol_or_symbols = [symbol],
    timeframe=TimeFrame(amount = 1, unit = TimeFrameUnit.Hour), # specify timeframe
    start = now - timedelta(days = 1),                          # specify start datetime, default=the beginning of the current day.
    # end_date=None,                                        # specify end datetime, default=now
    limit = 2,                                               # specify limit
)
crypto_historical_data_client.get_crypto_bars(req).df

# %%
# get historical quote by symbol
# ref. https://docs.alpaca.markets/reference/cryptoquotes-1
now = datetime.now(ZoneInfo("America/New_York"))
req = CryptoQuoteRequest(
    symbol_or_symbols = [symbol],
    start = now - timedelta(days = 1),                          # specify start datetime, default=the beginning of the current day.
    # end_date=None,                                        # specify end datetime, default=now
    limit = 2,                                               # specify limit
)
crypto_historical_data_client.get_crypto_quotes(req).df

# %%
# get historical trades by symbol
req = CryptoTradesRequest(
    symbol_or_symbols = [symbol],
    start = now - timedelta(days = 1),                          # specify start datetime, default=the beginning of the current day.
    # end=None,                                             # specify end datetime, default=now
    limit = 2,                                                # specify limit
)
crypto_historical_data_client.get_crypto_trades(req).df

# %%
# get latest quotes by symbol
req = CryptoLatestQuoteRequest(
    symbol_or_symbols = [symbol],
)
res = crypto_historical_data_client.get_crypto_latest_quote(req)
res
